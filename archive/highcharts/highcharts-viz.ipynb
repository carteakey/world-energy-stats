# %%
import pandas as pd

df = pd.read_csv("env/hadoop-hive-spark/notebooks/output/insight-1.csv")

df.head()
# Out:
#    year  renewables_consumption  fossil_fuel_consumption
# 0  1990                6863.432                83064.320
# 1  1991                7032.226                83294.062
# 2  1992                7059.343                83769.078
# 3  1993                7474.867                83915.758
# 4  1994                7548.948                84960.594

# %%
from highcharts_core.chart import Chart
from highcharts_core.options import HighchartsOptions
from highcharts_core.options.title import Title
from highcharts_core.options.axes.x_axis import XAxis
from highcharts_core.options.axes.y_axis import YAxis
from highcharts_core.options.plot_options.scatter import ScatterOptions
from highcharts_core.options.series.area import LineSeries
from highcharts_core.options.axes.title import AxisTitle
from highcharts_core.options.axes.accessibility import AxisAccessibility

insight_1_a = LineSeries.from_pandas(
    df,
    series_type="line",
    property_map={"y": "renewables_consumption", "x": "year"},
)

insight_1_b = LineSeries.from_pandas(
    df,
    series_type="line",
    property_map={"y": "fossil_fuel_consumption", "x": "year"},
)
options = HighchartsOptions(
    title=Title(text="Trend of Energy Consumption over the years"),
    y_axis=YAxis(title=AxisTitle(text="Energy Consumption (Terawatt-hours)")),
    x_axis=XAxis(
        accessibility=AxisAccessibility(range_description="Year: 1990 to 2022")
    ),
)
insight_1 = Chart.from_options(options)
insight_1.add_series(insight_1_a, insight_1_b)

as_js_literal = insight_1.to_js_literal()
print(as_js_literal)
# Out:
# document.addEventListener('DOMContentLoaded', function() {
# Highcharts.chart(null,
# {
#   series: [{
#   data: [[1990,
# 6863.432],
# [1991,
# 7032.226],
# [1992,
# 7059.343],
# [1993,
# 7474.867],
# [1994,
# 7548.948],
# [1995,
# 7956.042],
# [1996,
# 8064.391],
# [1997,
# 8241.819],
# [1998,
# 8335.938],
# [1999,
# 8437.115],
# [2000,
# 8626.927],
# [2001,
# 8417.771],
# [2002,
# 8622.095],
# [2003,
# 8650.36],
# [2004,
# 9311.386],
# [2005,
# 9684.451],
# [2006,
# 10143.593],
# [2007,
# 10505.478],
# [2008,
# 11310.476],
# [2009,
# 11558.073],
# [2010,
# 12449.881],
# [2011,
# 12999.631],
# [2012,
# 13816.133],
# [2013,
# 14704.658],
# [2014,
# 15422.238],
# [2015,
# 15977.102],
# [2016,
# 16870.148],
# [2017,
# 17858.443],
# [2018,
# 18990.977],
# [2019,
# 19985.84],
# [2020,
# 21134.498],
# [2021,
# 22323.965],
# [2022,
# 23848.668]],
#   name: 'renewables_consumption',
#   type: 'line'
# },
# {
#   data: [[1990,
# 83064.32],
# [1991,
# 83294.062],
# [1992,
# 83769.078],
# [1993,
# 83915.758],
# [1994,
# 84960.594],
# [1995,
# 86531.617],
# [1996,
# 89078.883],
# [1997,
# 90023.977],
# [1998,
# 90476.656],
# [1999,
# 91940.5],
# [2000,
# 94406.922],
# [2001,
# 95559.0],
# [2002,
# 97669.164],
# [2003,
# 101887.992],
# [2004,
# 106794.469],
# [2005,
# 110509.383],
# [2006,
# 113618.281],
# [2007,
# 117489.945],
# [2008,
# 118344.031],
# [2009,
# 116038.727],
# [2010,
# 121502.586],
# [2011,
# 124557.797],
# [2012,
# 126339.219],
# [2013,
# 128002.844],
# [2014,
# 128770.164],
# [2015,
# 129421.867],
# [2016,
# 130300.273],
# [2017,
# 132517.438],
# [2018,
# 135556.359],
# [2019,
# 136105.719],
# [2020,
# 129446.438],
# [2021,
# 136585.125],
# [2022,
# 137236.672]],
#   name: 'fossil_fuel_consumption',
#   type: 'line'
# }],
#   title: {
#   text: 'Trend of Energy Consumption over the years'
# },
#   xAxis: {
#   accessibility: {
#   rangeDescription: 'Year: 1990 to 2022'
# }
# },
#   yAxis: {
#   title: {
#   text: 'Energy Consumption (Terawatt-hours)'
# }
# }
# },
# );
# });

# %%
import pandas as pd

df = pd.read_csv("env/hadoop-hive-spark/notebooks/output/insight-2.csv")

df = df[df['year']==2022]
df = df[df['country']=='Brazil']
# df.drop(columns=['country','year'],inplace=True)

# %%
json_df = df.transpose().to_json(orient='table')

import json
json_data = json.loads(json_df)
json_data['data']
# Out:
# [{'index': 'country', '0': 'Brazil'},
#  {'index': 'year', '0': 2022},
#  {'index': 'biofuel_share', '0': 6.4955538058},
#  {'index': 'coal_share', '0': 4.3669163308},
#  {'index': 'gas_share', '0': 8.5845120542},
#  {'index': 'oil_share', '0': 37.3355211496},
#  {'index': 'nuclear_share', '0': 0.9778593675},
#  {'index': 'hydro_share', '0': 29.8948070953},
#  {'index': 'solar_share', '0': 2.1086367823},
#  {'index': 'wind_share', '0': 5.7135938399},
#  {'index': 'other_renewables_share', '0': 4.5225995746}]

# %%
for index, row in df.iterrows():
    print(row)
# Out:
# country                      Brazil
# year                           2022
# biofuel_share              6.495554
# coal_share                 4.366916
# gas_share                  8.584512
# oil_share                 37.335521
# nuclear_share              0.977859
# hydro_share               29.894807
# solar_share                2.108637
# wind_share                 5.713594
# other_renewables_share       4.5226
# Name: 0, dtype: object
# country                      Canada
# year                           2022
# biofuel_share              0.598065
# coal_share                 2.729613
# gas_share                 30.960454
# oil_share                 30.170307
# nuclear_share              5.517621
# hydro_share               26.442171
# solar_share                0.399083
# wind_share                 2.490388
# other_renewables_share     0.692299
# Name: 33, dtype: object
# country                       China
# year                           2022
# biofuel_share              0.062955
# coal_share                 55.46918
# gas_share                  8.485533
# oil_share                 17.665416
# nuclear_share              2.360764
# hydro_share                7.673301
# solar_share                2.518555
# wind_share                 4.491042
# other_renewables_share     1.273254
# Name: 66, dtype: object
# country                     Germany
# year                           2022
# biofuel_share              1.015225
# coal_share                18.945188
# gas_share                 22.623977
# oil_share                 34.631868
# nuclear_share              2.541121
# hydro_share                1.335514
# solar_share                4.638955
# wind_share                 9.561258
# other_renewables_share     4.706894
# Name: 99, dtype: object
# country                       India
# year                           2022
# biofuel_share              0.357566
# coal_share                55.133703
# gas_share                  5.747442
# oil_share                 27.575431
# nuclear_share              1.141608
# hydro_share                 4.50491
# solar_share                2.450648
# wind_share                 1.803902
# other_renewables_share      1.28479
# Name: 132, dtype: object
# country                   Iran
# year                      2022
# biofuel_share              NaN
# coal_share                 NaN
# gas_share                  NaN
# oil_share                  NaN
# nuclear_share              NaN
# hydro_share                NaN
# solar_share                NaN
# wind_share                 NaN
# other_renewables_share     NaN
# Name: 165, dtype: object
# country                       Japan
# year                           2022
# biofuel_share              0.116178
# coal_share                27.551871
# gas_share                 20.277301
# oil_share                 37.043019
# nuclear_share              2.613455
# hydro_share                3.939109
# solar_share                5.386489
# wind_share                 0.429947
# other_renewables_share     2.642631
# Name: 198, dtype: object
# country                      Russia
# year                           2022
# biofuel_share              0.045317
# coal_share                11.056406
# gas_share                 50.842217
# oil_share                 24.417728
# nuclear_share              6.973208
# hydro_share                6.421145
# solar_share                0.077924
# wind_share                 0.136474
# other_renewables_share      0.02958
# Name: 231, dtype: object
# country                   South Korea
# year                             2022
# biofuel_share                0.244928
# coal_share                  22.622063
# gas_share                   17.543273
# oil_share                   43.042832
# nuclear_share               12.477316
# hydro_share                  0.261557
# solar_share                  1.992003
# wind_share                   0.248016
# other_renewables_share       1.568011
# Name: 264, dtype: object
# country                   United States
# year                               2022
# biofuel_share                  1.628518
# coal_share                    10.289184
# gas_share                      33.07634
# oil_share                     37.691483
# nuclear_share                  7.626441
# hydro_share                    2.530155
# solar_share                    2.017572
# wind_share                     4.297999
# other_renewables_share         0.842309
# Name: 297, dtype: object

# %%
from highcharts_core.chart import Chart
from highcharts_core.options import HighchartsOptions


options_as_str = """{
    chart: {
        plotShadow: false,
        type: 'pie'
    },
    title: {
        text: 'Brazil',
    },
    tooltip: {
        pointFormat: '{series.name}: <b>{point.percentage:.1f}%</b>'
    },
    accessibility: {
        point: {
            valueSuffix: '%'
        }
    },
    plotOptions: {
        pie: {
            allowPointSelect: true,
            cursor: 'pointer',
            dataLabels: {
                enabled: false
            },
            showInLegend: true
        }
    }
}"""
options = HighchartsOptions.from_js_literal(options_as_str)

# %%
chart = Chart.from_options(options)
chart.display()
# Out:
# <div id="highcharts_target_div_9QBGB8" style="width:100%; height:400;"></div>

# %%
from highcharts_core.chart import Chart
from highcharts_core.options.series.pie import PieSeries
from highcharts_core.options import HighchartsOptions
from highcharts_core.options.title import Title
from highcharts_core.options.axes.x_axis import XAxis
from highcharts_core.options.axes.y_axis import YAxis
from highcharts_core.options.axes.title import AxisTitle
from highcharts_core.options.axes.accessibility import AxisAccessibility

insight_2_a = PieSeries.from_pandas(
    df,
    series_type="pie",
    property_map={
        "y" : "0"
    }
)
insight_2_a

# chart.add_series(insight_2_a)

# options = HighchartsOptions(
#     title=Title(text=""),
#     y_axis=YAxis(title=AxisTitle(text="Energy Consumption (Terawatt-hours)")),
#     x_axis=XAxis(
#         accessibility=AxisAccessibility(range_description="Year: 1990 to 2022")
#     ),
# )

# insight_2 = Chart.from_options(options)
# insight_2.add_series(insight_2_a)
# insight_2.display()
# Out:
# ---------------------------------------------------------------------------
# HighchartsPandasDeserializationError      Traceback (most recent call last)
# /root/world-energy-stats/highcharts-viz.ipynb Cell 8 line 1
#       <a href='vscode-notebook-cell://ssh-remote%2B142.93.154.227/root/world-energy-stats/highcharts-viz.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> from highcharts_core.options.axes.title import AxisTitle
#       <a href='vscode-notebook-cell://ssh-remote%2B142.93.154.227/root/world-energy-stats/highcharts-viz.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> from highcharts_core.options.axes.accessibility import AxisAccessibility
# ---> <a href='vscode-notebook-cell://ssh-remote%2B142.93.154.227/root/world-energy-stats/highcharts-viz.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> insight_2_a = PieSeries.from_pandas(
#      <a href='vscode-notebook-cell://ssh-remote%2B142.93.154.227/root/world-energy-stats/highcharts-viz.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a>     df,
#      <a href='vscode-notebook-cell://ssh-remote%2B142.93.154.227/root/world-energy-stats/highcharts-viz.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a>     series_type="pie",
#      <a href='vscode-notebook-cell://ssh-remote%2B142.93.154.227/root/world-energy-stats/highcharts-viz.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=12'>13</a>     property_map={
#      <a href='vscode-notebook-cell://ssh-remote%2B142.93.154.227/root/world-energy-stats/highcharts-viz.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=13'>14</a>         "y" : "0"
#      <a href='vscode-notebook-cell://ssh-remote%2B142.93.154.227/root/world-energy-stats/highcharts-viz.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=14'>15</a>     }
#      <a href='vscode-notebook-cell://ssh-remote%2B142.93.154.227/root/world-energy-stats/highcharts-viz.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=15'>16</a> )
#      <a href='vscode-notebook-cell://ssh-remote%2B142.93.154.227/root/world-energy-stats/highcharts-viz.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=16'>17</a> insight_2_a
#      <a href='vscode-notebook-cell://ssh-remote%2B142.93.154.227/root/world-energy-stats/highcharts-viz.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a> # chart.add_series(insight_2_a)
#      <a href='vscode-notebook-cell://ssh-remote%2B142.93.154.227/root/world-energy-stats/highcharts-viz.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a>
#      <a href='vscode-notebook-cell://ssh-remote%2B142.93.154.227/root/world-energy-stats/highcharts-viz.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a> # options = HighchartsOptions(
#    (...)
#      <a href='vscode-notebook-cell://ssh-remote%2B142.93.154.227/root/world-energy-stats/highcharts-viz.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=29'>30</a> # insight_2.add_series(insight_2_a)
#      <a href='vscode-notebook-cell://ssh-remote%2B142.93.154.227/root/world-energy-stats/highcharts-viz.ipynb#X10sdnNjb2RlLXJlbW90ZQ%3D%3D?line=30'>31</a> # insight_2.display()
#
# File ~/world-energy-stats/.venv/lib/python3.11/site-packages/highcharts_core/options/series/base.py:2109, in SeriesBase.from_pandas(cls, df, property_map, series_kwargs, series_in_rows, series_index, **kwargs)
#    2107 # SCENARIO 1: Has Property Map
#    2108 if property_map:
# -> 2109     series_list = cls._from_pandas_multi_map(df,
#    2110                                              property_map,
#    2111                                              series_kwargs,
#    2112                                              **kwargs)
#    2113     if len(series_list) == 1:
#    2114         return series_list[0]
#
# File ~/world-energy-stats/.venv/lib/python3.11/site-packages/highcharts_core/options/series/base.py:1831, in SeriesBase._from_pandas_multi_map(cls, df, property_map, series_kwargs, **kwargs)
#    1829 if map_value not in df.columns.values:
#    1830     if map_value != df.index.name:
# -> 1831         raise errors.HighchartsPandasDeserializationError(
#    1832             f'Unable to find a column labeled "{map_value}" in df.'
#    1833         )
#    1835 fixed_values[key] = map_value
#    1836 if key == 'y':
#
# HighchartsPandasDeserializationError: Unable to find a column labeled "0" in df.
